# %%
from io import StringIO
import requests
import json
import pandas as pd

# !wget --no-check-certificate  https://www.ecdc.europa.eu/sites/default/files/documents/COVID-19-geographic-disbtribution-worldwide-2020-04-27.xlsx df_data_1 = pd.read_csv("brent-daily_csv.csv")
df_data_1 = pd.read_excel("COVID-19-geographic-disbtribution-worldwide-2020-04-27.xlsx")
df_data_1=df_data_1.loc[df_data_1['countriesAndTerritories'] == 'Italy']
df_data_1.head()
# Out:
# --2020-04-27 16:18:46--  https://www.ecdc.europa.eu/sites/default/files/documents/COVID-19-geographic-disbtribution-worldwide-2020-04-27.xlsx
# Resolving www.ecdc.europa.eu (www.ecdc.europa.eu)... 52.85.156.56, 52.85.156.13, 52.85.156.18, ...
# Connecting to www.ecdc.europa.eu (www.ecdc.europa.eu)|52.85.156.56|:443... connected.
# WARNING: cannot verify www.ecdc.europa.eu's certificate, issued by 'CN=Amazon,OU=Server CA 1B,O=Amazon,C=US':
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 633081 (618K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: 'COVID-19-geographic-disbtribution-worldwide-2020-04-27.xlsx.6'
#
#      0K .......... .......... .......... .......... ..........  8%  351K 2s
#     50K .......... .......... .......... .......... .......... 16%  701K 1s
#    100K .......... .......... .......... .......... .......... 24% 2.31M 1s
#    150K .......... .......... .......... .......... .......... 32% 1.93M 1s
#    200K .......... .......... .......... .......... .......... 40% 1.48M 0s
#    250K .......... .......... .......... .......... .......... 48% 3.38M 0s
#    300K .......... .......... .......... .......... .......... 56% 1.28M 0s
#    350K .......... .......... .......... .......... .......... 64% 24.6M 0s
#    400K .......... .......... .......... .......... .......... 72% 4.33M 0s
#    450K .......... .......... .......... .......... .......... 80% 2.27M 0s
#    500K .......... .......... .......... .......... .......... 88% 1.32M 0s
#    550K .......... .......... .......... .......... .......... 97% 5.55M 0s
#    600K .......... ........                                   100% 23.3M=0.4s
#
# 2020-04-27 16:18:47 (1.41 MB/s) - 'COVID-19-geographic-disbtribution-worldwide-2020-04-27.xlsx.6' saved [633081/633081]
#
# --2020-04-27 16:18:47--  http://df_data_1/
# Resolving df_data_1 (df_data_1)... failed: No such host is known. .
# wget: unable to resolve host address 'df_data_1'
# --2020-04-27 16:18:49--  http://=/
# Resolving = (=)... failed: No such host is known. .
# wget: unable to resolve host address '='
# --2020-04-27 16:18:49--  http://pd.read_csv(brent-daily_csv.csv)/
# Resolving pd.read_csv(brent-daily_csv.csv) (pd.read_csv(brent-daily_csv.csv))... failed: No such host is known. .
# wget: unable to resolve host address 'pd.read_csv(brent-daily_csv.csv)'
# FINISHED --2020-04-27 16:18:49--
# Total wall clock time: 3.2s
# Downloaded: 1 files, 618K in 0.4s (1.41 MB/s)
#         dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 6451 2020-04-27   27      4  2020   2324     260                   Italy
# 6452 2020-04-26   26      4  2020   2357     415                   Italy
# 6453 2020-04-25   25      4  2020   3021     420                   Italy
# 6454 2020-04-24   24      4  2020   2646     464                   Italy
# 6455 2020-04-23   23      4  2020   3370     437                   Italy
#
#      geoId countryterritoryCode  popData2018 continentExp
# 6451    IT                  ITA   60431283.0       Europe
# 6452    IT                  ITA   60431283.0       Europe
# 6453    IT                  ITA   60431283.0       Europe
# 6454    IT                  ITA   60431283.0       Europe
# 6455    IT                  ITA   60431283.0       Europe

# %%
df_data_1['dateInt']=df_data_1['year'].astype(str) + df_data_1['month'].astype(str).str.zfill(2)+ df_data_1['day'].astype(str).str.zfill(2)
df_data_1['date'] = pd.to_datetime(df_data_1['dateInt'], format='%Y%m%d')

# %%
del df_data_1['month']
del df_data_1['day']
del df_data_1['dateInt']

# %%
df_data_1= df_data_1[['date','deaths']]
df_data_1=df_data_1.loc[df_data_1['date'] >= '2020-02-20']

# %%
df_data_1=df_data_1.sort_values(by=['date'])

# %%
print(df_data_1.shape)
# Out:
# (68, 2)

# %%
import matplotlib.pyplot as plt
# Visualising the results
import seaborn as sns
sns.set_style("darkgrid",  {"axes.facecolor": "1.9"})
sns.set_context("paper", font_scale=1.3)  
plt.figure(figsize=(15,5))
df_data_1_plot = df_data_1.iloc[:,1:2].values.astype(float)
# Visualising the Data
plt.plot(df_data_1_plot, color = 'red', label = 'Italy Fatalities')
plt.title('Italy Fatalities')
plt.xlabel('rank_by_date')
plt.ylabel('deaths')
plt.legend()
plt.show()

# %% [markdown]
# Stateful vs. Stateless LSTM
# --------------------------
#
# 1. **Stateless**: LSTM updates parameters on **batch 1** and then initiates cell states (meaning - memory, usually with zeros) for **batch 2**
# 2. **Stateful**: it uses batch 1 last output cell sates as initial states for batch 2.
#
# When to use which?
# ----------------
#
# - When  sequences in batches are related to each other (e.g. prices of one commodity), we should better use **stateful** mode
# - Else, when one sequence represents a complete sentence, we  should go with **stateless** mode

# %% [markdown]
# Batch-size: which batch-size to choose?
# ------------------------------------
#
# **Very important decision!**
#
# Imagine, you must learn to recognize a bird...
# You are presented images of different birds.
#
# What would you prefer:
# 1. To see the one image at a time, make your notes about special bird quilities (set your **weights**) and then see another bird and so on
# 2. **OR** may be you would better learn if you see - let's say 5 - bird images at ones. May be then you can faster notice the bird's intrinsic properties?
#
# I'd say - the second method is more efficient for humans. We need more examples of an entitiy, that we have to distinguish.
#
# **So the machines! Therefore we select a batch size of 64.
# Later in programming assigment we will see how the batch size impacts the prediction accuracy.**

# %%
#import packages
import numpy as np
import pandas as pd
from keras.preprocessing import sequence
from keras.models import load_model
# Out:
# Using TensorFlow backend.
# C:\Users\nick_\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\nick_\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\nick_\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\nick_\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\nick_\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\nick_\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# defining the batch size and number of epochs
batch_size = 12
epochs = 120
timesteps = 1

# %% [markdown]
# Batch-size and trainings-set size
# -------------------------------
#
# With **stateful LSTMs** the trainings-set size must be divisible without remainder by the batch-size (modulo = 0)

# %%
length = len(df_data_1)
print(length)
length *= 1 - 0.2
print(length)
# Out:
# 68
# 54.400000000000006

# %%
def get_train_length(dataset, batch_size, test_percent):
    # substract test_percent to be excluded from training, reserved for testset
    length = len(dataset)
    length *= 1 - test_percent
    train_length_values = []
    for x in range(int(length) - 12,int(length)): 
        modulo=x%batch_size
        if (modulo == 0):
            train_length_values.append(x)
            print(x)
    return (max(train_length_values))

# %%
length = get_train_length(df_data_1, batch_size, 0.2)
print(length)
# Out:
# 48
# 48

# %%
#Adding timesteps * 2
upper_train = length + timesteps*2
df_data_1_train = df_data_1[0:upper_train]
training_set = df_data_1_train.iloc[:,1:2].values
training_set.shape
# Out:
# (50, 1)

# %%
# Feature Scaling
#scale between 0 and 1. the weights are esier to find.
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(np.float64(training_set))
training_set_scaled.shape
# Out:
# (50, 1)

# %%
X_train = []
y_train = []

# Creating a data structure with n timesteps

print(length + timesteps)
for i in range(timesteps, length + timesteps): 
    X_train.append(training_set_scaled[i-timesteps:i,0])
    y_train.append(training_set_scaled[i:i+timesteps,0])

print(len(X_train))
print(len(y_train))
#create X_train matrix
#1 item per array (timestep) 
print(X_train[0:2])
print(np.array(X_train).shape)
#create Y_train matrix
#1 item per array (timestep) 
print(y_train[0:2])
print(np.array(y_train).shape)
# Out:
# 49
# 48
# 48
# [array([0.]), array([0.])]
# (48, 1)
# [array([0.]), array([0.])]
# (48, 1)

# %%
# Reshaping
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1], 1))
print(X_train.shape)
print(y_train.shape)
# Out:
# (48, 1, 1)
# (48, 1, 1)

# %%
# Building the LSTM
# Importing the Keras libraries and packages

from keras.layers import Dense
import tensorflow as tf
from keras.layers import Input, LSTM
from keras.models import Model
import h5py

# %%
# Initialising the LSTM Model with MAE Loss-Function
# Using Functional API

inputs_1_mae = Input(batch_shape=(batch_size,timesteps,1))
#each layer is the input of the next layer
lstm_1_mae = LSTM(10, stateful=True, return_sequences=True)(inputs_1_mae)
lstm_2_mae = LSTM(10, stateful=True, return_sequences=True)(lstm_1_mae)

output_1_mae = Dense(units = 1)(lstm_2_mae)

regressor_mae = Model(inputs=inputs_1_mae, outputs = output_1_mae)

#adam is fast starting off and then gets slower and more precise
#mae -> mean absolute error loss function
regressor_mae.compile(optimizer='adam', loss = 'mae')
regressor_mae.summary()
# Out:
# WARNING:tensorflow:From C:\Users\nick_\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (12, 1, 1)                0
# _________________________________________________________________
# lstm_1 (LSTM)                (12, 1, 10)               480
# _________________________________________________________________
# lstm_2 (LSTM)                (12, 1, 10)               840
# _________________________________________________________________
# dense_1 (Dense)              (12, 1, 1)                11
# =================================================================
# Total params: 1,331
# Trainable params: 1,331
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Citation from Redwood Center for Theoretical Neuroscince (Berkeley University)
# ---------------------
# http://redwood.berkeley.edu
#
# http://redwood.berkeley.edu/vs265/Brian-Cheung-LSTMS.pdf
#
# Overall LSTM Structure
# ----------------
# ![Screen%20Shot%202018-01-13%20at%2013.40.12.png](attachment:Screen%20Shot%202018-01-13%20at%2013.40.12.png)
#
#
# LSTM Node Anatomy
# ----------------
# ![Screen%20Shot%202018-01-13%20at%2013.26.12.png](attachment:Screen%20Shot%202018-01-13%20at%2013.26.12.png)

# %% [markdown]
# One of the best articles:
# -----------------------
# http://colah.github.io/posts/2015-08-Understanding-LSTMs/

# %% [markdown]
# How LSTM Param Number is computed?
# --------------------------------
#
# 1. To decide how to handle the memory each LSTM Cell has <bold>3 Gates</bold>:
#     - input (what to let in),
#     - forget (what to forget) and
#     - output (what to write to the output)
# 2. LSTM **Cell State** is its **memory**
# 3. LSTM Hidden State is equivalent to the Cell output:
#     - lstm_hidden_state_size (number of neurons = memory cells) = lstm_outputs_size
# 4. Parameters:
#     - weights for the inputs (lstm_inputs_size)
#     - weights for the outputs (lstm_outputs_size)
#     - bias variable
# 5.  Result from previous point - for all 3 Gates and for Cell State ( = 4)
#
#     \begin{equation}
#           \textbf{PARAMETERS} = \textbf4 \times \textbf{ LSTM outputs size} \times (\textbf{weights LSTM inputs size} + \textbf{weights LSTM outputs size} + 1 \textbf{ bias variable})
#     \end{equation}

# %%
# 1st LSTM Layer
parameters = 4 * 10 * (1 + 10 + 1)
print(parameters)
# Out:
# 480

# %%
parameters = 4 * 10 * (10 + 10 + 1)
print(parameters)
# Out:
# 840

# %%
#Statefull
for i in range(epochs):
    print("Epoch: " + str(i))
    #run through all data but the cell, hidden state are used for the next batch.
    regressor_mae.fit(X_train, y_train, shuffle=False, epochs = 1, batch_size = batch_size)
    #resets only the states but the weights, cell and hidden are kept.
    regressor_mae.reset_states()
    
#Stateless
#between the batches the cell and hidden states are lost.
#regressor_mae.fit(X_train, y_train, shuffle=False, epochs = epochs, batch_size = batch_size)
# Out:
# Epoch: 0
# WARNING:tensorflow:From C:\Users\nick_\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
# 48/48 [==============================] - 0s 8ms/step - loss: 0.3704
# Epoch: 1
# Epoch 1/1
# 48/48 [==============================] - 0s 104us/step - loss: 0.3621
# Epoch: 2
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.3563
# Epoch: 3
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.3508
# Epoch: 4
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.3456
# Epoch: 5
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.3410
# Epoch: 6
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.3365
# Epoch: 7
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.3323
# Epoch: 8
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.3281
# Epoch: 9
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.3240
# Epoch: 10
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.3199
# Epoch: 11
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.3156
# Epoch: 12
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.3110
# Epoch: 13
# Epoch 1/1
# 48/48 [==============================] - 0s 104us/step - loss: 0.3061
# Epoch: 14
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.3008
# Epoch: 15
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.2951
# Epoch: 16
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.2888
# Epoch: 17
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.2820
# Epoch: 18
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.2746
# Epoch: 19
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.2669
# Epoch: 20
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.2585
# Epoch: 21
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.2493
# Epoch: 22
# Epoch 1/1
# 48/48 [==============================] - 0s 142us/step - loss: 0.2391
# Epoch: 23
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.2279
# Epoch: 24
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.2157
# Epoch: 25
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.2026
# Epoch: 26
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1882
# Epoch: 27
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1729
# Epoch: 28
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1597
# Epoch: 29
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1493
# Epoch: 30
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1420
# Epoch: 31
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1372
# Epoch: 32
# Epoch 1/1
# 48/48 [==============================] - 0s 104us/step - loss: 0.1338
# Epoch: 33
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1330
# Epoch: 34
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1329
# Epoch: 35
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1326
# Epoch: 36
# Epoch 1/1
# 48/48 [==============================] - 0s 104us/step - loss: 0.1324
# Epoch: 37
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1327
# Epoch: 38
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1329
# Epoch: 39
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1332
# Epoch: 40
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1333
# Epoch: 41
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1335
# Epoch: 42
# Epoch 1/1
# 48/48 [==============================] - 0s 104us/step - loss: 0.1335
# Epoch: 43
# Epoch 1/1
# 48/48 [==============================] - 0s 115us/step - loss: 0.1335
# Epoch: 44
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1335
# Epoch: 45
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1334
# Epoch: 46
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1333
# Epoch: 47
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1330
# Epoch: 48
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1330
# Epoch: 49
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1330
# Epoch: 50
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1330
# Epoch: 51
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1330
# Epoch: 52
# Epoch 1/1
# 48/48 [==============================] - 0s 104us/step - loss: 0.1331
# Epoch: 53
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1331
# Epoch: 54
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1331
# Epoch: 55
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1332
# Epoch: 56
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1332
# Epoch: 57
# Epoch 1/1
# 48/48 [==============================] - 0s 146us/step - loss: 0.1332
# Epoch: 58
# Epoch 1/1
# 48/48 [==============================] - 0s 146us/step - loss: 0.1333
# Epoch: 59
# Epoch 1/1
# 48/48 [==============================] - ETA: 0s - loss: 0.066 - 0s 125us/step - loss: 0.1333
# Epoch: 60
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1333
# Epoch: 61
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1333
# Epoch: 62
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1334
# Epoch: 63
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1333
# Epoch: 64
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1330
# Epoch: 65
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1326
# Epoch: 66
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1323
# Epoch: 67
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1319
# Epoch: 68
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1316
# Epoch: 69
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1313
# Epoch: 70
# Epoch 1/1
# 48/48 [==============================] - 0s 104us/step - loss: 0.1311
# Epoch: 71
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1308
# Epoch: 72
# Epoch 1/1
# 48/48 [==============================] - 0s 104us/step - loss: 0.1306
# Epoch: 73
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1304
# Epoch: 74
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1301
# Epoch: 75
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1299
# Epoch: 76
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1297
# Epoch: 77
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1294
# Epoch: 78
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1291
# Epoch: 79
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1287
# Epoch: 80
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1283
# Epoch: 81
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1279
# Epoch: 82
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1275
# Epoch: 83
# Epoch 1/1
# 48/48 [==============================] - 0s 104us/step - loss: 0.1271
# Epoch: 84
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1267
# Epoch: 85
# Epoch 1/1
# 48/48 [==============================] - 0s 104us/step - loss: 0.1262
# Epoch: 86
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1258
# Epoch: 87
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1254
# Epoch: 88
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1249
# Epoch: 89
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1245
# Epoch: 90
# Epoch 1/1
# 48/48 [==============================] - 0s 104us/step - loss: 0.1240
# Epoch: 91
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1235
# Epoch: 92
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1231
# Epoch: 93
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1226
# Epoch: 94
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1221
# Epoch: 95
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1216
# Epoch: 96
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.1211
# Epoch: 97
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1206
# Epoch: 98
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1200
# Epoch: 99
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1195
# Epoch: 100
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1189
# Epoch: 101
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1183
# Epoch: 102
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1178
# Epoch: 103
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1172
# Epoch: 104
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1165
# Epoch: 105
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1159
# Epoch: 106
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1153
# Epoch: 107
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1146
# Epoch: 108
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1139
# Epoch: 109
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1133
# Epoch: 110
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1126
# Epoch: 111
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1118
# Epoch: 112
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1111
# Epoch: 113
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1104
# Epoch: 114
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1096
# Epoch: 115
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1089
# Epoch: 116
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1081
# Epoch: 117
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1072
# Epoch: 118
# Epoch 1/1
# 48/48 [==============================] - 0s 104us/step - loss: 0.1064
# Epoch: 119
# Epoch 1/1
# 48/48 [==============================] - 0s 125us/step - loss: 0.1055

# %%
#save model
import h5py
regressor_mae.save(filepath="my_model_with_mae_1_ts.h5")

# %%
def get_test_length(dataset, batch_size):
    
    test_length_values = []
    for x in range(len(dataset) - 12, len(dataset) - timesteps*2): 
        modulo=(x-upper_train)%batch_size
        if (modulo == 0):
            test_length_values.append(x)
            print(x)
    return (max(test_length_values))

# %%
test_length = get_test_length(df_data_1, batch_size)
print(test_length)
upper_test = test_length + timesteps*2
testset_length = test_length - upper_train
print(testset_length)
# Out:
# 62
# 62
# 12

# %%
print(upper_train, upper_test, len(df_data_1))
# Out:
# 50 64 68

# %%
# construct test set

#subsetting
df_data_1_test = df_data_1[upper_train:upper_test] 
test_set = df_data_1_test.iloc[:,1:2].values

#scaling
scaled_real_bcg_values_test = sc.fit_transform(np.float64(test_set))

#creating input data
X_test = []
for i in range(timesteps, testset_length + timesteps):
    X_test.append(scaled_real_bcg_values_test[i-timesteps:i, 0])
X_test = np.array(X_test)


#reshaping
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
#prediction
predicted_bcg_values_test_mae = regressor_mae.predict(X_test, batch_size=batch_size)
regressor_mae.reset_states()

print(predicted_bcg_values_test_mae.shape)

#reshaping
predicted_bcg_values_test_mae = np.reshape(predicted_bcg_values_test_mae, 
                                       (predicted_bcg_values_test_mae.shape[0], 
                                        predicted_bcg_values_test_mae.shape[1]))

print(predicted_bcg_values_test_mae.shape)
#inverse transform
predicted_bcg_values_test_mae = sc.inverse_transform(predicted_bcg_values_test_mae)


#creating y_test data
y_test = []
for j in range(0, testset_length - timesteps):
    y_test = np.append(y_test, predicted_bcg_values_test_mae[j, timesteps-1])

# reshaping
y_test = np.reshape(y_test, (y_test.shape[0], 1))

print(y_test.shape)
# Out:
# (12, 1, 1)
# (12, 1)
# (11, 1)

# %%
# Visualising the results
import seaborn as sns
sns.set_style("darkgrid",  {"axes.facecolor": "1.9"})
sns.set_context("paper", font_scale=1.3)  
plt.figure(figsize=(15,5))
plt.plot(test_set[timesteps:len(y_test)].astype(float), color = 'red', label = 'Real Fatilities')
plt.plot(y_test[0:len(y_test) - timesteps].astype(float), color = 'blue', label = 'Predicted Fatilities')
plt.title('Fatilities Prediction - MAE')
plt.xlabel('Time')
plt.ylabel('Fatilities')
plt.legend()
plt.show()

# %%
#MSE (mean sqared error)
import math
from sklearn.metrics import mean_squared_error
rmse = math.sqrt(mean_squared_error(test_set[timesteps:len(y_test)], y_test[0:len(y_test) - timesteps]))
print(rmse)
# Out:
# 82.73431120216469

# %%
#MAE (mean absolut error)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(test_set[timesteps:len(y_test)], y_test[0:len(y_test) - timesteps])
print(mae)
# Out:
# 72.40887451171875

# %%
# Initialising the LSTM Model with MSE Loss Function

inputs_1_mse = Input(batch_shape=(batch_size,timesteps,1))
lstm_1_mse = LSTM(10, stateful=True, return_sequences=True)(inputs_1_mse)
lstm_2_mse = LSTM(10, stateful=True, return_sequences=True)(lstm_1_mse)

output_1_mse = Dense(units = 1)(lstm_2_mse)

regressor_mse = Model(inputs=inputs_1_mse, outputs = output_1_mse)

#mse -> mean squared error as loss function
regressor_mse.compile(optimizer='adam', loss = 'mse')
regressor_mse.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (12, 1, 1)                0
# _________________________________________________________________
# lstm_3 (LSTM)                (12, 1, 10)               480
# _________________________________________________________________
# lstm_4 (LSTM)                (12, 1, 10)               840
# _________________________________________________________________
# dense_2 (Dense)              (12, 1, 1)                11
# =================================================================
# Total params: 1,331
# Trainable params: 1,331
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 120
for i in range(epochs):
    print("Epoch: " + str(i))
    regressor_mse.fit(X_train, y_train, shuffle=False, epochs = 1, batch_size = batch_size)
    regressor_mse.reset_states()
# Out:
# Epoch: 0
# Epoch 1/1
# 48/48 [==============================] - 0s 9ms/step - loss: 0.2379
# Epoch: 1
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.2276
# Epoch: 2
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.2175
# Epoch: 3
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.2073
# Epoch: 4
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1972
# Epoch: 5
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.1871
# Epoch: 6
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.1769
# Epoch: 7
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.1668
# Epoch: 8
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.1567
# Epoch: 9
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.1467
# Epoch: 10
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.1367
# Epoch: 11
# Epoch 1/1
# 48/48 [==============================] - 0s 208us/step - loss: 0.1267
# Epoch: 12
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.1169
# Epoch: 13
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.1073
# Epoch: 14
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0980
# Epoch: 15
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0889
# Epoch: 16
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0802
# Epoch: 17
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0720
# Epoch: 18
# Epoch 1/1
# 48/48 [==============================] - 0s 176us/step - loss: 0.0644
# Epoch: 19
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0573
# Epoch: 20
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0510
# Epoch: 21
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0455
# Epoch: 22
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0407
# Epoch: 23
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0368
# Epoch: 24
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0336
# Epoch: 25
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0312
# Epoch: 26
# Epoch 1/1
# 48/48 [==============================] - 0s 147us/step - loss: 0.0294
# Epoch: 27
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0282
# Epoch: 28
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0274
# Epoch: 29
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0268
# Epoch: 30
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0265
# Epoch: 31
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0263
# Epoch: 32
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0261
# Epoch: 33
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0260
# Epoch: 34
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0259
# Epoch: 35
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0258
# Epoch: 36
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0258
# Epoch: 37
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0257
# Epoch: 38
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0257
# Epoch: 39
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0256
# Epoch: 40
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0256
# Epoch: 41
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0255
# Epoch: 42
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0254
# Epoch: 43
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0254
# Epoch: 44
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0253
# Epoch: 45
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0253
# Epoch: 46
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0252
# Epoch: 47
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0252
# Epoch: 48
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0251
# Epoch: 49
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0251
# Epoch: 50
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0250
# Epoch: 51
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0250
# Epoch: 52
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0250
# Epoch: 53
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0250
# Epoch: 54
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 55
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 56
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 57
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 58
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 59
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 60
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0249
# Epoch: 61
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 62
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0249
# Epoch: 63
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 64
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 65
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0249
# Epoch: 66
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 67
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 68
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0249
# Epoch: 69
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0249
# Epoch: 70
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 71
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0249
# Epoch: 72
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 73
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0249
# Epoch: 74
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0249
# Epoch: 75
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 76
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0249
# Epoch: 77
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0249
# Epoch: 78
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 79
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 80
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0249
# Epoch: 81
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 82
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0249
# Epoch: 83
# Epoch 1/1
# 48/48 [==============================] - 0s 146us/step - loss: 0.0249
# Epoch: 84
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 85
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 86
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 87
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 88
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0249
# Epoch: 89
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0248
# Epoch: 90
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0248
# Epoch: 91
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0248
# Epoch: 92
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0248
# Epoch: 93
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0248
# Epoch: 94
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0247
# Epoch: 95
# Epoch 1/1
# 48/48 [==============================] - 0s 208us/step - loss: 0.0247
# Epoch: 96
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0247
# Epoch: 97
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0246
# Epoch: 98
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0246
# Epoch: 99
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0246
# Epoch: 100
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0245
# Epoch: 101
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0245
# Epoch: 102
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0244
# Epoch: 103
# Epoch 1/1
# 48/48 [==============================] - 0s 208us/step - loss: 0.0244
# Epoch: 104
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0243
# Epoch: 105
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0243
# Epoch: 106
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0242
# Epoch: 107
# Epoch 1/1
# 48/48 [==============================] - 0s 145us/step - loss: 0.0242
# Epoch: 108
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0241
# Epoch: 109
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0241
# Epoch: 110
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0240
# Epoch: 111
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0240
# Epoch: 112
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0239
# Epoch: 113
# Epoch 1/1
# 48/48 [==============================] - 0s 177us/step - loss: 0.0238
# Epoch: 114
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0238
# Epoch: 115
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0237
# Epoch: 116
# Epoch 1/1
# 48/48 [==============================] - 0s 187us/step - loss: 0.0236
# Epoch: 117
# Epoch 1/1
# 48/48 [==============================] - 0s 178us/step - loss: 0.0236
# Epoch: 118
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0235
# Epoch: 119
# Epoch 1/1
# 48/48 [==============================] - 0s 166us/step - loss: 0.0234

# %%
import h5py
regressor_mse.save(filepath="model_mse_1_ts.h5")

# %%
predicted_bcg_values_test_mse = regressor_mse.predict(X_test, batch_size=batch_size)
regressor_mse.reset_states()

predicted_bcg_values_test_mse = np.reshape(predicted_bcg_values_test_mse, 
                                       (predicted_bcg_values_test_mse.shape[0], 
                                        predicted_bcg_values_test_mse.shape[1]))
predicted_bcg_values_test_mse = sc.inverse_transform(predicted_bcg_values_test_mse)

pred_mse = []

for j in range(0, testset_length - timesteps):
    pred_mse = np.append(pred_mse, predicted_bcg_values_test_mse[j, timesteps-1])

pred_mse = np.reshape(pred_mse, (pred_mse.shape[0], 1))

# %%
# Visualising the results
import seaborn as sns
sns.set_style("darkgrid",  {"axes.facecolor": "1.9"})
sns.set_context("paper", font_scale=1.3)  
plt.figure(figsize=(15,5))
plt.plot(test_set[timesteps:len(pred_mse)].astype(float), color = 'red', label = 'Real Fatilities')
plt.plot(pred_mse[0:len(pred_mse) - timesteps], color = 'green', label = 'Predicted Fatilities with MSE')
plt.plot(y_test[0:len(y_test) - timesteps].astype(float), color = 'blue', label = 'Predicted Fatilities with MAE')
plt.title('Predicted Fatilities - MSE')
plt.xlabel('Time')
plt.ylabel('Fatilities')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
rmse = math.sqrt(mean_squared_error(test_set[timesteps:len(pred_mse)], pred_mse[0:len(pred_mse) - timesteps]))
print(rmse)
# Out:
# 90.46867137199425

# %%
mean = np.mean(np.float64(test_set[timesteps:len(pred_mse)]))
print(mean)
# Out:
# 537.9

# %%
rmse/mean * 100
# Out:
# 16.81886435619897

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(test_set[timesteps:len(pred_mse)], pred_mse[0:len(pred_mse) - timesteps])
print(mae)
# Out:
# 79.13971557617188

# %%
mae/mean * 100
# Out:
# 14.712719013975068

# %%
data=df_data_1.loc[df_data_1['date'] >= '2020-04-12']

# %%
# construct set FOR FUTURE OBSERVATIONS FOR MSE

#subsetting
df_data_1_test = data
test_set = df_data_1_test.iloc[:,1:2].values

#scaling
scaled_real_bcg_values_test = sc.fit_transform(np.float64(test_set))

#creating input data
X_test = []
for i in range(timesteps, testset_length + timesteps):
    X_test.append(scaled_real_bcg_values_test[i-timesteps:i, 0])
X_test = np.array(X_test)


#reshaping
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
#prediction FUTURE OBSERVATIONS FOR MSE
predicted_bcg_values_test_mse = regressor_mse.predict(X_test, batch_size=batch_size)
regressor_mse.reset_states()

predicted_bcg_values_test_mse = np.reshape(predicted_bcg_values_test_mse, 
                                       (predicted_bcg_values_test_mse.shape[0], 
                                        predicted_bcg_values_test_mse.shape[1]))
predicted_bcg_values_test_mse = sc.inverse_transform(predicted_bcg_values_test_mse)

pred_mse = []

for j in range(0, testset_length - timesteps):
    pred_mse = np.append(pred_mse, predicted_bcg_values_test_mse[j, timesteps-1])

pred_mse = np.reshape(pred_mse, (pred_mse.shape[0], 1))

# %%
# construct set FOR FUTURE OBSERVATIONS FOR MAE
#subsetting
test_set = data.iloc[:,1:2].values

#scaling
scaled_real_bcg_values_test = sc.fit_transform(np.float64(test_set))

#creating input data
X_test = []
for i in range(timesteps, testset_length + timesteps):
    X_test.append(scaled_real_bcg_values_test[i-timesteps:i, 0])
X_test = np.array(X_test)


#reshaping
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
#prediction FUTURE OBSERVATIONS FOR MAE
predicted_bcg_values_test_mae = regressor_mae.predict(X_test, batch_size=batch_size)
regressor_mae.reset_states()

print(predicted_bcg_values_test_mae.shape)

#reshaping
predicted_bcg_values_test_mae = np.reshape(predicted_bcg_values_test_mae, 
                                       (predicted_bcg_values_test_mae.shape[0], 
                                        predicted_bcg_values_test_mae.shape[1]))

print(predicted_bcg_values_test_mae.shape)
#inverse transform
predicted_bcg_values_test_mae = sc.inverse_transform(predicted_bcg_values_test_mae)
# Out:
# (12, 1, 1)
# (12, 1)

# %%
# Visualising the results
import seaborn as sns
sns.set_style("darkgrid",  {"axes.facecolor": "1.9"})
sns.set_context("paper", font_scale=1.3)  
plt.figure(figsize=(15,5))
plt.plot(predicted_bcg_values_test_mae[0:len(predicted_bcg_values_test_mae) - timesteps], color = 'blue', label = 'LSTM MODEL_MAE Predicted Fatilities the following days')
plt.plot(pred_mse[0:len(pred_mse) ], color = 'green', label = 'LSTM MODEL_MSE Predicted Fatilities the following days')
plt.title('Predicted Future Fatilities - MSE')
plt.xlabel('Time')
plt.ylabel('Fatilities')
plt.legend()
plt.show()

# %%
predicted_bcg_values_test_mae
# Out:
# array([[436.32916],
#        [343.58823],
#        [410.10382],
#        [429.3162 ],
#        [416.90536],
#        [390.81375],
#        [415.4544 ],
#        [368.18616],
#        [344.58386],
#        [355.0922 ],
#        [395.30243],
#        [346.5782 ]], dtype=float32)

# %%
MAE=pd.DataFrame(predicted_bcg_values_test_mae[0:len(predicted_bcg_values_test_mae) - timesteps])

# %%
MSE=pd.DataFrame(pred_mse)

# %%
MSE.columns = ['MSE']

# %%
MAE.columns = ['MAE']

# %%
FUTURE=pd.concat([MSE, MAE], axis=1)

# %%
REAL=df_data_1

# %%
 Date=pd.DataFrame(pd.date_range('2020-04-28', periods=11, freq='D'))

# %%
Date.columns = ['Date']

# %%
FUTURE=pd.concat([Date,MSE, MAE], axis=1)

# %%
FUTURE
# Out:
#          Date         MSE         MAE
# 0  2020-04-28  374.068207  436.329163
# 1  2020-04-29  328.441193  343.588226
# 2  2020-04-30  360.760834  410.103821
# 3  2020-05-01  370.458313  429.316193
# 4  2020-05-02  364.164673  416.905365
# 5  2020-05-03  351.248108  390.813751
# 6  2020-05-04  363.436035  415.454407
# 7  2020-05-05  340.276062  368.186157
# 8  2020-05-06  328.920380  344.583862
# 9  2020-05-07  333.973999  355.092194
# 10 2020-05-08  353.445526  395.302429

# %%
REAL
# Out:
#            date  deaths
# 6518 2020-02-20       0
# 6517 2020-02-21       0
# 6516 2020-02-22       0
# 6515 2020-02-23       2
# 6514 2020-02-24       0
# ...         ...     ...
# 6455 2020-04-23     437
# 6454 2020-04-24     464
# 6453 2020-04-25     420
# 6452 2020-04-26     415
# 6451 2020-04-27     260
#
# [68 rows x 2 columns]

# %%
fig, ax = plt.subplots(1, figsize=(16, 12))
ax.plot(REAL['date'], REAL['deaths'], color="red", label="Actual Fatalities", linewidth=3)
ax.plot(FUTURE['Date'],FUTURE['MSE'], color="green", label="Projected Fatilities LSTM MSE", linewidth=3)
ax.plot(FUTURE['Date'], FUTURE['MAE'], color="blue", label="Projected Fatilities LSTM MAE", linewidth=3)
plt.legend(loc="upper left", frameon=True, fontsize=12)

plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14)
